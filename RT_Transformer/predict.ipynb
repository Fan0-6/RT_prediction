# %%
import torch
import numpy as np
from model import MyNet
from load_data import checkdataset,traindataset

# %%
check_dataset = checkdataset('./check')
print(len(check_dataset))
# Out:
# 268

# %%
train_dataset = traindataset('./train/train_data')
print(len(train_dataset))
# Out:
# Processing...
# /Users/liufanling/Documents/GitHub/sta221/RT_Transformer_hilic/load_data.py:581: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   hybridization_encoder.fit(torch.range(0, len(hybridization_list) - 1).unsqueeze(-1))
# /Users/liufanling/Documents/GitHub/sta221/RT_Transformer_hilic/load_data.py:585: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   atom_encoder.fit(torch.range(0, len(atom_list) - 1).unsqueeze(-1))
# ...

# %%
check_dataset
# Out:
# checkdataset(268)

# %%
# Create a DataLoader for batch processing
val_loader = DataLoader(check_dataset, batch_size=32, shuffle=False)
# Out:
# /Users/liufanling/miniconda3/envs/pyretip/lib/python3.10/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
# Load the trained model
model = MyNet
model.load_state_dict(torch.load('./model/best_model2.pkl'))
model.eval()  # Set to evaluation mode
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Load the trained model
#       2 model = MyNet
# ----> 3 model.load_state_dict(torch.load('./model/best_model2.pkl'))
#       4 model.eval()  # Set to evaluation mode
#
# TypeError: Module.load_state_dict() missing 1 required positional argument: 'state_dict'

# %%
# Move model to the appropriate device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Prepare the validation dataset
# Assuming `validation_dataset` is a PyTorch Geometric dataset
validation_loader = DataLoader(check_data, batch_size=32, shuffle=False)

# Run predictions
all_predictions = []
all_true_values = []

with torch.no_grad():
    for data in validation_loader:
        data = data.to(device)
        predictions = model(data)  # Forward pass
        all_predictions.append(predictions.cpu().numpy())
        all_true_values.append(data.y.cpu().numpy())

# Combine predictions and true values
all_predictions = np.concatenate(all_predictions)
all_true_values = np.concatenate(all_true_values)

# Print or save the results
print("Predictions:", all_predictions)
print("True Values:", all_true_values)

# Optionally save predictions to a file
np.savetxt("predictions.csv", all_predictions, delimiter=",", header="Predictions", comments="")
